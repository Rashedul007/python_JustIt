# %% [markdown]
# # Pandas, Matplotlib and Seaborn

# %%
import pandas as pd

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %% [markdown]
# [Dataset Soruce](https://www.kaggle.com/datasets/rajkumarpandey02/gdp-in-usd-per-capita-income-by-country)

# %% [markdown]
# CONTENT
# <p>The figures presented here do not take into account differences in the cost of living in different countries, and the results vary greatly from one year to another based on fluctuations in the exchange rates of the country's currency. Such fluctuations change a country's ranking from one year to the next, even though they often make little or no difference to the standard of living of its population.
#
# GDP per capita is often considered an indicator of a country's standard of living; however, this is inaccurate because GDP per capita is not a measure of personal income.
#
# Comparisons of national income are also frequently made on the basis of purchasing power parity (PPP), to adjust for differences in the cost of living in different countries. (See List of countries by GDP (PPP) per capita.) PPP largely removes the exchange rate problem but not others; it does not reflect the value of economic output in international trade, and it also requires more estimation than GDP per capita. On the whole, PPP per capita figures are more narrowly spread than nominal GDP per capita figures.</p>

# %%
df = pd.read_csv("GDP (nominal) per Capita.csv",encoding= 'unicode_escape',  index_col=0)  # makes col named 0 the index col

# %% [markdown]
# # EDA (Exploratory Data Analysis)

# %%
df.head()
# df.head(10)
# df.tail(10)
# Out:
#   Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 1            Monaco    Europe             0         0              234316
# 2     Liechtenstein    Europe             0         0              157755
# 3        Luxembourg    Europe        132372      2023              133590
# 4           Ireland    Europe        114581      2023              100172
# 5           Bermuda  Americas             0         0              114090
#
#    WorldBank_Year  UN_Estimate UN_Year
# 1            2021       234317    2021
# 2            2020       169260    2021
# 3            2021       133745    2021
# 4            2021       101109    2021
# 5            2021       112653    2021

# %%
df.shape
# Out:
# (223, 8)

# %%
df["UN_Region"].value_counts()
# Out:
# Africa      55
# Asia        51
# Europe      48
# Americas    48
# Oceania     20
# World        1
# Name: UN_Region, dtype: int64

# %%
df[df["UN_Region"]=="World"]
# Out:
#    Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 93             World     World         13440      2023               12235
#
#     WorldBank_Year  UN_Estimate UN_Year
# 93            2021        12230    2021

# %% [markdown]
# ## Which countris below average by IMF world estimate?

# %% [markdown]
# ### IMF estiamte 0 values

# %%
df[df["IMF_Estimate"]==0]
# Out:
#               Country/Territory UN_Region  IMF_Estimate  IMF_Year  \
# 1                        Monaco    Europe             0         0
# 2                 Liechtenstein    Europe             0         0
# 5                       Bermuda  Americas             0         0
# 9                   Isle of Man    Europe             0         0
# 10               Cayman Islands  Americas             0         0
# 14              Channel Islands    Europe             0         0
# 15                Faroe Islands    Europe             0         0
# 19                    Greenland  Americas             0         0
# 31       British Virgin Islands  Americas             0         0
# 37            US Virgin Islands  Americas             0         0
# 39                New Caledonia   Oceania             0         0
# 42                         Guam   Oceania             0         0
# 58    Sint Maarten (Dutch part)  Americas             0         0
# 61     Northern Mariana Islands   Oceania             0         0
# 65   Saint Martin (French part)  Americas             0         0
# 68     Turks and Caicos Islands  Americas             0         0
# 71             French Polynesia   Oceania             0         0
# 76                 Cook Islands   Oceania             0         0
# 77                     Anguilla  Americas             0         0
# 82                     Cura̤ao  Americas             0         0
# 85                   Montserrat  Americas             0         0
# 86               American Samoa   Oceania             0         0
# 104                        Cuba  Americas             0         0
# 196                    Zanzibar    Africa             0         0
# 204                       Syria      Asia             0         0
# 212                 North Korea      Asia             0         0
#
#      WorldBank_Estimate  WorldBank_Year  UN_Estimate UN_Year
#
# Out:
#   Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 1            Monaco    Europe             0         0              234316
#
#    WorldBank_Year  UN_Estimate UN_Year
# 1            2021       234317    2021

# %%
df.nlargest(1, 'WorldBank_Estimate').loc[:,["Country/Territory", "WorldBank_Estimate"]]
# Out:
#   Country/Territory  WorldBank_Estimate
# 1            Monaco              234316

# %%
df[["Country/Territory", "WorldBank_Estimate"]].nlargest(1, 'WorldBank_Estimate')  # find largetst from 2 cols
# Out:
#   Country/Territory  WorldBank_Estimate
# 1            Monaco              234316

# %%
df[df["IMF_Estimate"]==0]
#df["IMF_Estimate"]==0   # without using df outside - will result in boolean result row wise
# Out:
#               Country/Territory UN_Region  IMF_Estimate  IMF_Year  \
# 1                        Monaco    Europe             0         0
# 2                 Liechtenstein    Europe             0         0
# 5                       Bermuda  Americas             0         0
# 9                   Isle of Man    Europe             0         0
# 10               Cayman Islands  Americas             0         0
# 14              Channel Islands    Europe             0         0
# 15                Faroe Islands    Europe             0         0
# 19                    Greenland  Americas             0         0
# 31       British Virgin Islands  Americas             0         0
# 37            US Virgin Islands  Americas             0         0
# 39                New Caledonia   Oceania             0         0
# 42                         Guam   Oceania             0         0
# 58    Sint Maarten (Dutch part)  Americas             0         0
# 61     Northern Mariana Islands   Oceania             0         0
# 65   Saint Martin (French part)  Americas             0         0
# 68     Turks and Caicos Islands  Americas             0         0
# 71             French Polynesia   Oceania             0         0
# 76                 Cook Islands   Oceania             0         0
# 77                     Anguilla  Americas             0         0
# 82                     Cura̤ao  Americas             0         0
# 85                   Montserrat  Americas             0         0
# 86               American Samoa   Oceania             0         0
# 104                        Cuba  Americas             0         0
# 196                    Zanzibar    Africa             0         0
# 204                       Syria      Asia             0         0
# 212                 North Korea      Asia             0         0
#
#      WorldBank_Estimate  WorldBank_Year  UN_Estimate UN_Year
# 1                234316            2021       234317    2021
# 2                157755            2020       169260    2021
# 5                114090            2021       112653    2021
# 9                 87158            2019            0       0
# 10                86569            2021        85250    2021
# 14                75153            2007            0       0
# 15                69010            2021            0       0
# 19                54571            2020        58185    2021
# 31                    0               0        49444    2021
# 37                39552            2020            0       0
# 39                37160            2021        34994    2021
# 42                35905            2021            0       0
# 58                28988            2018        26199    2021
# 61                23707            2019            0       0
# 65                21921            2014            0       0
# 68                20909            2021        20909    2021
# 71                19915            2021        19915    2021
# 76                    0               0        19264    2021
# 77                    0               0        19216    2021
# 82                17718            2021        14183    2021
# 85                    0               0        16199    2021
# 86                15743            2021            0       0
# 104                9500            2020        11255    2021
# 196                   0               0         1211    2021
# 204                 533            2020          925    2021
# 212                   0               0          654    2021

# %% [markdown]
# #### ----- sort_values()

# %%
df.sort_values(by="UN_Estimate", ascending=False).head(1)
# Out:
#   Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 1            Monaco    Europe             0         0              234316
#
#    WorldBank_Year  UN_Estimate UN_Year
# 1            2021       234317    2021

# %%
df.sort_values(by="UN_Estimate", ascending=False).loc[:,["Country/Territory", "WorldBank_Estimate"]]
# Out:
#            Country/Territory  WorldBank_Estimate
# 1                     Monaco              234316
# 2              Liechtenstein              157755
# 3                 Luxembourg              133590
# 5                    Bermuda              114090
# 4                    Ireland              100172
# ..                       ...                 ...
# 37         US Virgin Islands               39552
# 42                      Guam               35905
# 46                    Taiwan                   0
# 61  Northern Mariana Islands               23707
# 86            American Samoa               15743
#
# [223 rows x 2 columns]

# %% [markdown]
# #### ---- str.startswith( )  , str.contains( )

# %%
df[df["Country/Territory"].str.startswith("U")]    # filters row data
# Out:
#         Country/Territory UN_Region  IMF_Estimate  IMF_Year  \
# 12          United States  Americas         80034      2023
# 30   United Arab Emirates      Asia         49451      2023
# 33         United Kingdom    Europe         46371      2023
# 37      US Virgin Islands  Americas             0         0
# 66                Uruguay  Americas         21677      2023
# 143               Ukraine    Europe          4654      2023
# 171            Uzbekistan      Asia          2563      2023
# 199                Uganda    Africa          1105      2023
#
#      WorldBank_Estimate  WorldBank_Year  UN_Estimate UN_Year
# 12                70249            2021        69185    2021
# 30                44316            2021        43295    2021
# 33                46510            2021        46542    2021
# 37                39552            2020            0       0
# 66                17313            2021        17313    2021
# 143                4836            2021         4596    2021
# 171                1983            2021         2032    2021
# 199                 884            2021          930    2021

# %%
df.loc[:, df.columns.str.startswith('U')]    # filters col name
# Out:
#     UN_Region  UN_Estimate UN_Year
# 1      Europe       234317    2021
# 2      Europe       169260    2021
# 3      Europe       133745    2021
# 4      Europe       101109    2021
# 5    Americas       112653    2021
# ..        ...          ...     ...
# 219    Africa          613    2021
# 220    Africa          400    2021
# 221    Africa          505    2021
# 222      Asia          373    2021
# 223    Africa          311    2021
#
# [223 rows x 3 columns]

# %%
df[df["Country/Territory"].str.contains("United")]
# Out:
#        Country/Territory UN_Region  IMF_Estimate  IMF_Year  \
# 12         United States  Americas         80034      2023
# 30  United Arab Emirates      Asia         49451      2023
# 33        United Kingdom    Europe         46371      2023
#
#     WorldBank_Estimate  WorldBank_Year  UN_Estimate UN_Year
# 12               70249            2021        69185    2021
# 30               44316            2021        43295    2021
# 33               46510            2021        46542    2021

# %%
df.tail(15)
# Out:
#             Country/Territory UN_Region  IMF_Estimate  IMF_Year  \
# 209                   Eritrea    Africa           715      2023
# 210                  DR Congo    Africa           695      2023
# 211                      Chad    Africa           667      2023
# 212               North Korea      Asia             0         0
# 213                     Niger    Africa           613      2023
# 214                Mozambique    Africa           587      2023
# 215                     Yemen      Asia           573      2023
# 216                   Somalia    Africa           544      2023
# 217                Madagascar    Africa           536      2023
# 218  Central African Republic    Africa           534      2023
# 219                    Malawi    Africa           496      2023
# 220               South Sudan    Africa           467      2023
# 221              Sierra Leone    Africa           415      2023
# 222               Afghanistan      Asia           611      2020
# 223                   Burundi    Africa           249      2023
#
#      WorldBank_Estimate  WorldBank_Year  UN_Estimate UN_Year
# 209                 644            2011          623    2021
# 210                 577            2021          551    2021
# 211                 686            2021          955    2021
# 212                   0               0          654    2021
# 213                 591            2021          591    2021
# 214                 492            2021          492    2021
# 215                 702            2018          302    2021
# 216                 447            2021          447    2021
# 217                 501            2021          500    2021
# 218                 461            2021          461    2021
# 219                 635            2021          613    2021
# 220                1072            2015          400    2021
# 221                 480            2021          505    2021
# 222                 369            2021          373    2021
# 223                 222            2021          311    2021

# %% [markdown]
# ## Checking Missing Values

# %%
df.isnull()

# %%
df.isnull().any()

# %%
df.isnull().sum()

# %%
df.isnull().sum().sum()

# %%
df.isnull().values.any(axis=1) # axis = 1 is column
#df.isnull().values.any(axis=0) # axis = 0 is row

# %% [markdown]
# ## Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Histogram

# %%
df.hist(figsize=(12,9))
plt.show()

# %%
df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].hist(figsize=(12,9))

plt.show()

# %%
df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].hist(bins=5, figsize =(12,9))  # by default bin size is 10

plt.show()

## bin size is the number of columns in the visual histagram. Each colum consists of a range of values. not the area gridlines - its the histagram columns
## here each hist col represents - how many countries have IMF_Estimate from 0-24000[a bin] or 24001-57000[another bin] 
## eg- for bin [0-24000] 176 countries have that imf_est

# %%
df["WorldBank_Estimate"].agg(["min","max"])
# Out:
# min         0
# max    234316
# Name: WorldBank_Estimate, dtype: int64

# %%
234316/5
# bin size = 5. All 0 to 234316 values divided into 5 bins
# it will have 46863.2 in each hist col.i.e- in each bin
# Out:
# 46863.2

# %%
234316/10
#1 bin size if bins not given any number
# Out:
# 23431.6

# %%
df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].hist(bins=3, figsize=(12,9))

plt.show()

# %%
df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].hist(bins=15, figsize=(15,12))


plt.show()

# %% [markdown]
# ### Correlation Heatmap

# %%
df.corr(numeric_only = True)
# Out:
#                     IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# IMF_Estimate               1.000     0.248               0.588
# IMF_Year                   0.248     1.000              -0.317
# WorldBank_Estimate         0.588    -0.317               1.000
# WorldBank_Year             0.085     0.416               0.117
# UN_Estimate                0.627    -0.211               0.930
#
#                     WorldBank_Year  UN_Estimate
# IMF_Estimate                 0.085        0.627
# IMF_Year                     0.416       -0.211
# WorldBank_Estimate           0.117        0.930
# WorldBank_Year               1.000        0.017
# UN_Estimate                  0.017        1.000

# %%
corr = df.corr(numeric_only = True)

plt.figure(figsize=(9,6))
sns.heatmap(corr)

plt.show()

# %%
corr = df.corr(numeric_only = True)

plt.figure(figsize=(9,6))

sns.heatmap(corr, annot=True)

plt.show()

# %%
corr = df.corr()

plt.figure(figsize=(9,6))

sns.heatmap(corr, annot=True, cmap = 'GnBu')

plt.show()

# %%
corr = df.corr()

plt.figure(figsize=(9,6))

sns.heatmap(corr, annot=True, cmap = 'Purples')

plt.title("Correlation Map")


plt.show()

# %% [markdown]
# ### Bar plot

# %%
df.head()
# Out:
#   Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 1            Monaco    Europe             0         0              234316
# 2     Liechtenstein    Europe             0         0              157755
# 3        Luxembourg    Europe        132372      2023              133590
# 4           Ireland    Europe        114581      2023              100172
# 5           Bermuda  Americas             0         0              114090
#
#    WorldBank_Year  UN_Estimate UN_Year
# 1            2021       234317    2021
# 2            2020       169260    2021
# 3            2021       133745    2021
# 4            2021       101109    2021
# 5            2021       112653    2021

# %%
sns.barplot(x="UN_Region", y="WorldBank_Estimate", data=df, ci=None)

plt.show()

# %%
sns.barplot(x="WorldBank_Estimate", y="UN_Region", data=df, ci=None)

plt.show()

# %%
fig = plt.figure(figsize = (8,5))

ax = sns.barplot(x = "IMF_Estimate",  y = "UN_Region",  
data = df, ci = None)

ax.bar_label(ax.containers[0])

plt.show()

# %%
fig = plt.figure(figsize = (8,5)) 
ax = sns.barplot(x = "UN_Region",  y = "IMF_Estimate", 
                 data = df, ci = None) 

ax.bar_label(ax.containers[0]) 


ax.set_title("My title")
plt.show()

# %% [markdown]
# ### Scatter Plot

# %%
df.plot(x='UN_Region', y='UN_Estimate', kind='scatter',
        figsize=(10,6),
        title="Scatter Plot")

plt.show()

# %% [markdown]
# ### Boxplot and Outliers

# %%
sns.boxplot(x=df["UN_Estimate"])

plt.show()

# %%
df[df["UN_Estimate"]>50000].head()
# Out:
#   Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 1            Monaco    Europe             0         0              234316
# 2     Liechtenstein    Europe             0         0              157755
# 3        Luxembourg    Europe        132372      2023              133590
# 4           Ireland    Europe        114581      2023              100172
# 5           Bermuda  Americas             0         0              114090
#
#    WorldBank_Year  UN_Estimate UN_Year
# 1            2021       234317    2021
# 2            2020       169260    2021
# 3            2021       133745    2021
# 4            2021       101109    2021
# 5            2021       112653    2021

# %%
sns.boxplot(x=df["WorldBank_Estimate"])

plt.show()

# %%
sns.boxplot(x=df["IMF_Estimate"])

plt.show()

# %%
df[df["UN_Estimate"]>100000]
# Out:
#   Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 1            Monaco    Europe             0         0              234316
# 2     Liechtenstein    Europe             0         0              157755
# 3        Luxembourg    Europe        132372      2023              133590
# 4           Ireland    Europe        114581      2023              100172
# 5           Bermuda  Americas             0         0              114090
#
#    WorldBank_Year  UN_Estimate UN_Year
# 1            2021       234317    2021
# 2            2020       169260    2021
# 3            2021       133745    2021
# 4            2021       101109    2021
# 5            2021       112653    2021

# %%
df.UN_Estimate.mean()
# Out:
# 17767.304932735427

# %%
df.shape
# Out:
# (223, 8)

# %% [markdown]
# ## Create another dataframe called data excluding  5 countries with highest UN estimate

# %%
data = df[-(df["UN_Estimate"]>100000)]

# %%
data.head()
# Out:
#    Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 6             Norway    Europe        101103      2023               89154
# 7        Switzerland    Europe         98767      2023               91992
# 8          Singapore      Asia         91100      2023               72794
# 9        Isle of Man    Europe             0         0               87158
# 10    Cayman Islands  Americas             0         0               86569
#
#     WorldBank_Year  UN_Estimate UN_Year
# 6             2021        89242    2021
# 7             2021        93525    2021
# 8             2021        66822    2021
# 9             2019            0       0
# 10            2021        85250    2021

# %%
data.shape
# Out:
# (218, 8)

# %%
data.head()
# Out:
#    Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 6             Norway    Europe        101103      2023               89154
# 7        Switzerland    Europe         98767      2023               91992
# 8          Singapore      Asia         91100      2023               72794
# 9        Isle of Man    Europe             0         0               87158
# 10    Cayman Islands  Americas             0         0               86569
#
#     WorldBank_Year  UN_Estimate UN_Year
# 6             2021        89242    2021
# 7             2021        93525    2021
# 8             2021        66822    2021
# 9             2019            0       0
# 10            2021        85250    2021

# %%
data.UN_Estimate.mean()
# Out:
# 14729.47247706422

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sns.boxplot(x=data["UN_Estimate"])
plt.show()

# %% [markdown]
# ## Removing outliers

# %%
lower_q = df["UN_Estimate"].quantile(0.25)
lower_q
# Out:
# 2039.0

# %%
higher_q = df["UN_Estimate"].quantile(0.75)
higher_q
# Out:
# 20740.0

# %%
df_filtered = df[(df["UN_Estimate"] < higher_q) & (df["UN_Estimate"] > lower_q)]

# %%
df_filtered.head()
# Out:
#    Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 63            Greece    Europe         22595      2023               20193
# 64              Oman      Asia         21960      2023               19510
# 66           Uruguay  Americas         21677      2023               17313
# 67          Barbados  Americas         21085      2023               17226
# 69            Guyana  Americas         20539      2023                9999
#
#     WorldBank_Year  UN_Estimate UN_Year
# 63            2021        20571    2021
# 64            2021        19509    2021
# 66            2021        17313    2021
# 67            2021        17225    2021
# 69            2021         9999    2021

# %%
df_filtered.shape
# Out:
# (111, 8)

# %% [markdown]
# ##### There were 223 rows. now there are only around half.

# %%
df_filtered.UN_Estimate.mean()
# Out:
# 7934.8378378378375

# %%
#how can we create a table with following 
df_filtered.WorldBank_Estimate.mean()
# Out:
# 7555.414414414415

# %%
df_filtered.UN_Estimate.mean()
# Out:
# 7934.8378378378375

# %%
df_filtered.IMF_Estimate.mean()
# Out:
# 8276.324324324325

# %% [markdown]
# # way -2 ... like in R programming

# %% [markdown]
# ![image.png](attachment:image.png)
